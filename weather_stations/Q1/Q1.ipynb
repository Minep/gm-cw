# %%
import earthquake as eq
import numpy as np

# %%
data = np.loadtxt("earthquake_files\EarthquakeExerciseData.txt")

# %%
number_of_points = 2000
station_number = data.size
std = 0.2
all_stations, spiral_coord, station_coord, one_explosion = eq.earthquake_exercise_setup(station_number, std, number_of_points=number_of_points)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19636/3209553366.py in <module>
#       2 station_number = data.size
#       3 std = 0.2
# ----> 4 all_stations, spiral_coord, station_coord, one_explosion = eq.earthquake_exercise_setup(station_number, std, number_of_points=number_of_points)
#
# d:\ucl cs\COMP0080\Q1\earthquake.py in earthquake_exercise_setup(station_number, std, number_of_points)
#      44         for j in range(points_on_spiral):
#      45             for k in range(points_on_spiral):
# ---> 46                 v[j,k] = hypothesis[j, station] + hypothesis[k, station] + std*np.random.randn()
#      47         all_stations_prior.append(v)
#      48
#
# KeyboardInterrupt:

# %%
eq.q1(data, number_of_points, std, all_stations, spiral_coord, station_coord)

# %%
eq.q2(data, number_of_points, std, all_stations=all_stations, one_explosion=one_explosion)
# Out:
# 738.6482166401561
